# %%
### https://docs.langchain.com/oss/python/integrations/document_loaders

# %%
# !pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (0.1.7)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain_openai) (0.1.53)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain_openai) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (0.1.147)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (2.11.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.3,>=0.1.46->langchain_openai) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (0.26.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.13.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain_openai) (3.6)
# Requirement already satisfied: certifi in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain_openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain_openai) (3.9.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain_openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain_openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain_openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain_openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.2.0)
# Requirement already satisfied: colorama in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.24.0->langchain_openai) (0.4.6)

# %%
# !pip install langchain_experimental
# Out:
# Requirement already satisfied: langchain_experimental in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (0.0.58)
# Requirement already satisfied: langchain<0.2.0,>=0.1.17 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain_experimental) (0.1.20)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain_experimental) (0.1.53)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (0.6.4)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (0.0.38)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (2.11.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain<0.2.0,>=0.1.17->langchain_experimental) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.2.0,>=0.1.52->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langchain-core<0.2.0,>=0.1.52->langchain_experimental) (23.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.17->langchain_experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.17->langchain_experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.17->langchain_experimental) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.17->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain_experimental) (2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (0.26.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (3.9.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.17->langchain_experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.17->langchain_experimental) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.17->langchain_experimental) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.17->langchain_experimental) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.17->langchain_experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.17->langchain_experimental) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.17->langchain_experimental) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.17->langchain_experimental) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.2.0,>=0.1.17->langchain_experimental) (3.0.3)
# Requirement already satisfied: anyio in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.17->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\premalatha\downloads\openai\.conda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.17->langchain_experimental) (1.0.0)

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/refs/heads/main/CardioGoodFitness-1.csv")

# %%
### Display random 10 records
### Describe

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 50    TM195   29    Male         18     Partnered      3        3   68220
# 68    TM195   38    Male         16     Partnered      3        3   46617
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 32    TM195   25  Female         16     Partnered      2        2   40932
# 38    TM195   26  Female         16        Single      3        3   36384
# 90    TM498   23    Male         16     Partnered      4        3   45480
# 126   TM498   34    Male         16     Partnered      3        4   59124
# 48    TM195   28    Male         14        Single      4        3   54576
# 85    TM498   21    Male         16     Partnered      2        2   34110
# 2     TM195   19  Female         14     Partnered      4        3   30699
#
#      Miles
# 50      85
# 68      75
# 173    360
# 32      47
# 38      66
# 90     127
# 126     85
# 48     113
# 85      42
# 2       66

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  103.194444
# std       0.958869   16506.684226   51.863605
# min       1.000000   29562.000000   21.000000
# 25%       3.000000   44058.750000   66.000000
# 50%       3.000000   50596.500000   94.000000
# 75%       4.000000   58668.000000  114.750000
# max       5.000000  104581.000000  360.000000

# %%
from langchain_openai import OpenAI
llm=OpenAI()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 from langchain_openai import OpenAI
# ----> 2 llm=OpenAI()
#
# File c:\Users\Premalatha\Downloads\openai\.conda\Lib\site-packages\pydantic\v1\main.py:347, in BaseModel.__init__(__pydantic_self__, **data)
#     345 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     346 if validation_error:
# --> 347     raise validation_error
#     348 try:
#     349     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for OpenAI
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass `openai_api_key` as a named parameter. (type=value_error)

# %%
agent=create_pandas_dataframe_agent(llm,df,verbose=True,allow_dangerous_code=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
agent.run("How many rows are there?")

# %%
agent.run("How many are using TM 195?")

# %%
df['Product'].value_counts()

# %%
agent.run("What is the fitness level of 18 years old?")

# %%
agent.run("Show the unique Products with piechart")

# %%
agent.run("Show the unique Products with interactive piechart ")

# %%
agent.run("The Problem Statement is to predict the relationship between Product and Customer Characteristics.")

# %%
agent.run("Make KNN model and calculate the accuracy")

# %%
agent.run("Is Fitness numerical?")

# %%
agent.run("You are wrong?")

# %%
agent.run("Why is TM798 count less")

# %%
df1=df.copy()

# %%
agent=create_pandas_dataframe_agent(llm,[df,df1],verbose=True,allow_dangerous_code=True)

# %%
agent.run("Compare the dataframes and show the different records")

# %%
### usecase-2 (llm,tool,memory)
#### Import all the packages
#### key
### initialize
### define a function for the tool
### tool-> name,func(defining above),description
### memory-> chat history
### agent-> tool,llm,agent type,memory
### run agent

# %%
pip install langchainhub
from langchainhub import hub

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai
# !pip install langchain==0.1.16
# !pip install langchain-openai==0.0.5

# %%
from langchain.agents import initialize_agent, Tool
from langchain.agents.agent_types import AgentType
from langchain.memory import ConversationBufferMemory
from langchain.chat_models import ChatOpenAI
import os

# %%
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"]=userdata.get('openai')

# %%
llm=ChatOpenAI(temperature=0) #fact

# %%
def simple_calc(input: str) -> str:
    return str(eval(input))

# %%
tools=[Tool(name="Calculator",func=simple_calc,description="Useful for basic math")]

# %%
memory=ConversationBufferMemory(memory_key="chat_history")

# %%
agent=initialize_agent(tools=tools,llm=llm,memory=memory,verbose=True,)

# %%
response1=agent.run("What is 24 multiplied by 7")

# %%
response2=agent.run("Now add 400 to it.")

# %%
response1 = agent.run("What is 24 * 17?")
print("Agent:", response1)

response2 = agent.run("Now add 100 to it.")
print("Agent:", response2)

response3 = agent.run("Subtract 10.")
print("Agent:", response3)

# %%
### Fix remembering chat history

# %%
### File reader (txt),web search (duckduckgosearch)
### define function for file reader
### Tools

# %%
def file_reader_tool(query: str) -> str:
    try:
        with open("/content/training_data.txt", "r") as file:
            content = file.read()
            return content[:1000]
    except Exception as e:
        return f"Error reading file: {str(e)}"

# %%
# !pip install duckduckgo-search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

# %%
search=DuckDuckGoSearchRun()

# %%
tools = [

    Tool(
        name="FileReader",
        func=file_reader_tool,
        description="Reads content from a local text file called training_data.txt."
    ),
    Tool(
        name="WebSearch",
        func=search.run,
        description="Useful for answering questions about current events or facts using the internet."
    )
]

# %%
agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent=AgentType.CONVERSATIONAL_REACT_DESCRIPTION,
    verbose=True,
    memory=memory
)

# %%
agent.run("Read the file and tell me the content")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
agent.run("What is the date today?")

# %%
print(agent.run("Who is the current CEO of OpenAI.Use websearch"))

# %%
### Assessment-> RAG Agent
